# %%
# pip install bs4
# pip install selenium
# pip install requests
# pip install webdriver-manager

# %% [markdown]
# https://medium.com/analytics-vidhya/web-scraping-google-search-results-with-selenium-and-beautifulsoup-4c534817ad88

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
# Import the beautifulsoup and request libraries of python.
import requests
import bs4

# %%
# chrome_options = webdriver.ChromeOptions()
# chrome_options.add_argument("--headless")
# driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=chrome_options)
# import ssl
# ssl._create_default_https_context = ssl._create_unverified_context

# %%
# from ast import Num
# from magic_google import MagicGoogle
# import pprint

# PROXIES = None
# # PROXIES = [{
# #     'http': 'http://192.168.2.207:1080',
# #     'https': 'http://192.168.2.207:1080'
# # }]

# # Or MagicGoogle()
# mg = MagicGoogle(PROXIES)
# links=[]
# # Crawling url
# for url in mg.search_url(query='site:upenn.edu "innovation"', num=1000):
#     links.append(url)

# %%
import pandas as pd
ECOSYSTEM_PENN_LIST = [
'https://www.sas.upenn.edu/',
'https://venturelab.upenn.edu/',
'https://www.asc.upenn.edu/',
'https://www.dental.upenn.edu/',
'https://www.design.upenn.edu/',
'https://www.gse.upenn.edu/',
'https://www.seas.upenn.edu/',
'https://www.law.upenn.edu/',
'https://www.med.upenn.edu/',
'https://www.nursing.upenn.edu/',
'https://www.sp2.upenn.edu/',
'https://www.vet.upenn.edu/',
'https://pci.upenn.edu/',
'https://www.library.upenn.edu/',
'https://www.chop.edu/',
'https://sciencecenter.org/',
'https://wistar.org/',
'https://www.upenn.edu/research-and-innovation',
'https://research.upenn.edu/',
'https://research.upenn.edu/centers-and-institutes/',
'https://www.pennovation.upenn.edu/the-community#innovators',
'https://penntoday.upenn.edu/subtopic/innovation',
'https://yprize.upenn.edu/',
'https://belabs.seas.upenn.edu/',
'https://healthtech.upenn.edu/',
'https://www.pennpstar.org/',
'https://www.law.upenn.edu/institutes/ctic/',
'https://www.law.upenn.edu/futureprofessioninitiative/',
'https://www.pennovation.upenn.edu/',
'https://pci.upenn.edu/entrepreneurs/i-corps/',
'https://injury.research.chop.edu/',
'https://www.itmat.upenn.edu/',
'https://bakerretail.wharton.upenn.edu/']
df5 = pd.DataFrame(ECOSYSTEM_PENN_LIST)

# %%
import pandas as pd
df1 = pd.read_csv('GoogleSearchData/siteupenn.edu innovation (1).csv',delimiter=';')
df2 = pd.read_csv('GoogleSearchData/siteupenn.edu innovation (2).csv',delimiter=';')
df3 = pd.read_csv('GoogleSearchData/siteupenn.edu innovation (3).csv',delimiter=';')
df4 = pd.read_csv('GoogleSearchData/siteupenn.edu innovation (4).csv',delimiter=';')
df1 = df1.Url
df2 = df2.Url
df3 = df3.Url
df4 = df4.Url

# %%
from dataclasses import replace
df = pd.concat([df1,df2,df3,df4,df5])
df = df.reset_index().drop(columns=['index'])
df.drop_duplicates(inplace=True)
df.rename(columns={0:'url'}, inplace=True)
df.to_csv('total_links.csv')

# %%
import pandas as pd
df_links = pd.read_csv('total_links.csv', index_col=0)

# %%
# Domains that we do not consider as an innovation unit
EXCLUDE_DOMAIN = ['https://catalog.upenn.edu',
'https://curf.upenn.edu',
'https://hub.provost.upenn.edu',
'https://www.business-services.upenn.edu',
'https://www.collegehouses.upenn.edu',
'https://www.elp.upenn.edu',
'https://www.hr.upenn.edu',
'https://www.upenn.edu',
'https://apps.wharton.upenn.edu',
'https://ware.house.upenn.edu',
'https://undergrad-inside.wharton.upenn.edu',
'https://global.upenn.edu',
'https://www.impact.upenn.edu']

# %%
df_links.head()
# Out:
#                                                  url
# 0          https://www.nursing.upenn.edu/innovation/
# 1  https://www.nursing.upenn.edu/innovation/innov...
# 2  https://knowledge.wharton.upenn.edu/article/bu...
# 3  https://knowledge.wharton.upenn.edu/category/i...
# 4  https://www.med.upenn.edu/evpdean/innovation.html

# %%
sum(df_links.url.duplicated()) # check for duplication
# Out:
# 0

# %%
len(df_links)
# Out:
# 418

# %% [markdown]
# ### Exclude pdf websties

# %%
print(df_links[df_links.url.str.endswith("pdf")])
# exclude pdf links
df_links = df_links[~df_links.url.str.endswith("pdf")]
# Out:
#                                                    url
# 26   https://mackinstitute.wharton.upenn.edu/wp-con...
# 83   https://mackinstitute.wharton.upenn.edu/wp-con...
# 89   https://executiveeducation.wharton.upenn.edu/w...
# 150  https://ideas.wharton.upenn.edu/wp-content/upl...
# 167  https://faculty.wharton.upenn.edu/wp-content/u...
# 221  https://mackinstitute.wharton.upenn.edu/wp-con...
# 245  https://mackinstitute.wharton.upenn.edu/wp-con...
# 248  https://mackinstitute.wharton.upenn.edu/wp-con...
# 277  http://www-management.wharton.upenn.edu/pennin...
# 377  https://www.aisp.upenn.edu/wp-content/uploads/...

# %%
df_links.shape
# Out:
# (408, 1)

# %% [markdown]
# ### Branch as a domain

# %%
domains_branch_clickable = []
for link in df_links.url:
    link_element = link.split('/')
    print(len(link_element))
    if len(link_element[3]) > 0:
        print(link_element)
        a = "https://" + link_element[2]
        domains_branch_clickable.append(a)
        for i in range(3, len(link_element)-1):
            a += "/" + link_element[i]
            domains_branch_clickable.append(a)
# Out:
# 5
# ['https:', '', 'www.nursing.upenn.edu', 'innovation', '']
# 6
# ['https:', '', 'www.nursing.upenn.edu', 'innovation', 'innovation-accelerator', '']
# 6
# ['https:', '', 'knowledge.wharton.upenn.edu', 'article', 'business-model-innovation-matters-ever', '']
# 6
# ['https:', '', 'knowledge.wharton.upenn.edu', 'category', 'innovation', '']
# 5
# ['https:', '', 'www.med.upenn.edu', 'evpdean', 'innovation.html']
# 7
# ['https:', '', 'executiveeducation.wharton.upenn.edu', 'for-individuals', 'all-programs', 'mastering-innovation-strategy-process-and-tools', '']
# 4
# 6
# ['https:', '', 'globalyouth.wharton.upenn.edu', 'programs-courses', 'essentials-of-innovation', '']
# 6
# ['https:', '', 'www.law.upenn.edu', 'institutes', 'ctic', '']
# 4
# 6
# ['https:', '', 'www.hr.upenn.edu', 'PennHR', 'penn-community', 'inclusion-innovation-impact']
# 6
# ['https:', '', 'knowledge.wharton.upenn.edu', 'article', 'innovation-networks-looking-for-ideas-outside-the-company', '']
# 4
# 6
# ...

# %%
domains_branch_clickable =set(domains_branch_clickable)

# %%
len(domains_branch_clickable)
# Out:
# 433

# %%
domains_branch_clickable
# Out:
# {'https://aisp.upenn.edu/resources',
#  'https://aisp.upenn.edu/resources/aisp-innovation-expert-panel-reports',
#  'https://almanac.upenn.edu/articles',
#  'https://apps.wharton.upenn.edu/syllabi',
#  'https://apps.wharton.upenn.edu/syllabi/2019A',
#  'https://apps.wharton.upenn.edu/syllabi/2019A/FNCE250002',
#  'https://apps.wharton.upenn.edu/syllabi/2019A/MGMT927002',
#  'https://catalog.upenn.edu/graduate',
#  'https://catalog.upenn.edu/graduate/programs',
#  'https://catalog.upenn.edu/graduate/programs/entrepreneurship-innovation-mba',
#  'https://catalog.upenn.edu/graduate/programs/health-care-innovation-certificate',
#  'https://catalog.upenn.edu/graduate/programs/health-care-innovation-mhci',
#  'https://catalog.upenn.edu/undergraduate',
#  'https://catalog.upenn.edu/undergraduate/programs',
#  'https://catalog.upenn.edu/undergraduate/programs/entrepreneurship-innovation-bs',
#  'https://cemb.upenn.edu/programs',
#  'https://cemb.upenn.edu/programs/graduate-training',
# ...

# %%
from requests_html import HTMLSession
innovate_count = []
for i in domains_branch_clickable:
    session = HTMLSession()
    # page = requests.get(i, verify=False)
    # count = page.text.lower().count('innovat')
    # print(i)
    try: 
        r = session.get(i)
        count = r.html.full_text.lower().count('innovat')
        innovate_count.append(count)
    except: 
        continue
innovate_count
# Out:
# [7,
#  42,
#  6,
#  47,
#  0,
#  5,
#  7,
#  5,
#  44,
#  8,
#  3,
#  132,
#  2,
#  4,
#  29,
#  28,
#  9,
#  5,
#  2,
#  2,
#  29,
#  9,
#  2,
#  35,
#  115,
#  96,
#  20,
#  5,
#  33,
#  5,
#  29,
#  10,
#  47,
#  8,
#  42,
#  34,
#  44,
#  29,
#  9,
#  12,
#  4,
#  6,
#  26,
#  11,
#  59,
#  50,
#  2,
#  19,
#  33,
#  30,
#  27,
#  105,
#  5,
#  4,
#  1,
#  111,
#  0,
#  2,
#  9,
#  13,
#  152,
#  31,
#  8,
#  2,
#  49,
#  14,
#  27,
#  0,
#  21,
#  2,
#  2,
#  14,
#  6,
#  13,
#  25,
#  0,
#  2,
#  27,
#  125,
#  4,
#  2,
#  2,
#  59,
#  4,
#  139,
#  6,
#  95,
#  15,
#  123,
#  2,
#  6,
#  8,
#  8,
#  4,
#  56,
#  44,
#  4,
#  1,
#  2,
#  17,
#  5,
#  57,
#  10,
#  8,
#  0,
#  67,
#  41,
#  50,
#  8,
#  12,
#  1,
#  42,
#  26,
#  109,
#  36,
#  4,
#  13,
#  0,
#  28,
#  89,
#  5,
#  48,
#  26,
#  40,
#  21,
#  2,
#  25,
#  2,
#  2,
#  9,
#  10,
#  2,
#  2,
#  2,
#  5,
#  24,
#  2,
#  89,
#  2,
#  23,
#  6,
#  5,
#  23,
#  32,
#  2,
#  0,
#  62,
#  0,
#  2,
#  39,
#  52,
#  35,
# ...

# %%
data_branch = list(zip(domains_branch_clickable,innovate_count))

# %%
data_branch
# Out:
# [('https://www.gse.upenn.edu/about-penn-gse', 7),
#  ('https://mackinstitute.wharton.upenn.edu/corporate-partnership/collaborative-innovation-program-partners',
#   42),
#  ('https://cemb.upenn.edu/programs', 6),
#  ('https://executiveeducation.wharton.upenn.edu/thought-leadership/wharton-at-work/2017/03/need-more-innovation',
#   47),
#  ('https://scholarship.law.upenn.edu/faculty_scholarship', 0),
#  ('https://executiveeducation.wharton.upenn.edu/thought-leadership/wharton-at-work/2013/10',
#   5),
#  ('https://cemb.upenn.edu/programs/graduate-training', 7),
#  ('https://executiveeducation.wharton.upenn.edu/thought-leadership/wharton-at-work/2019/07',
#   5),
#  ('https://mackinstitute.wharton.upenn.edu/students/collaborative-innovation-program/projects-fall-2022',
#   44),
#  ('https://scholarship.law.upenn.edu/faculty_scholarship/1832', 8),
#  ('https://catalog.upenn.edu/graduate/programs', 3),
# ...

# %%
df_branch = pd.DataFrame(data_branch, columns=['domains_branch_clickable','innovate_count'])

# %%
pd.set_option('max_colwidth', 800)
df_branch
# Out:
#                                                                                          domains_branch_clickable  \
# 0                                                                        https://www.gse.upenn.edu/about-penn-gse
# 1         https://mackinstitute.wharton.upenn.edu/corporate-partnership/collaborative-innovation-program-partners
# 2                                                                                 https://cemb.upenn.edu/programs
# 3    https://executiveeducation.wharton.upenn.edu/thought-leadership/wharton-at-work/2017/03/need-more-innovation
# 4                                                           https://scholarship.law.upenn.edu/faculty_scholarship
# ..                                                                                                            ...
# 425                                 https://knowledge.wharton.upenn.edu/article/can-lean-co-exist-with-innovation
# ...

# %%
df_branch
# Out:
#                                                                                          domains_branch_clickable  \
# 0                                                                        https://www.gse.upenn.edu/about-penn-gse
# 1         https://mackinstitute.wharton.upenn.edu/corporate-partnership/collaborative-innovation-program-partners
# 2                                                                                 https://cemb.upenn.edu/programs
# 3    https://executiveeducation.wharton.upenn.edu/thought-leadership/wharton-at-work/2017/03/need-more-innovation
# 4                                                           https://scholarship.law.upenn.edu/faculty_scholarship
# ..                                                                                                            ...
# 425                                 https://knowledge.wharton.upenn.edu/article/can-lean-co-exist-with-innovation
# ...

# %%
df_branch_innovat = df_branch[df_branch.domains_branch_clickable.str.contains("innovat")]
df_branch_innovat
# Out:
#                                                                                                            domains_branch_clickable  \
# 1                           https://mackinstitute.wharton.upenn.edu/corporate-partnership/collaborative-innovation-program-partners
# 3                      https://executiveeducation.wharton.upenn.edu/thought-leadership/wharton-at-work/2017/03/need-more-innovation
# 8                              https://mackinstitute.wharton.upenn.edu/students/collaborative-innovation-program/projects-fall-2022
# 11                       https://knowledge.wharton.upenn.edu/article/vijay-govindarajan-how-reverse-innovation-can-change-the-world
# 19                                                                                https://healthcareinnovation.upenn.edu/leadership
# ..                                                                                                                              ...
# ...

# %%
df_links
# Out:
#                                                                                      url
# 0                                              https://www.nursing.upenn.edu/innovation/
# 1                       https://www.nursing.upenn.edu/innovation/innovation-accelerator/
# 2    https://knowledge.wharton.upenn.edu/article/business-model-innovation-matters-ever/
# 3                               https://knowledge.wharton.upenn.edu/category/innovation/
# 4                                      https://www.med.upenn.edu/evpdean/innovation.html
# ..                                                                                   ...
# 416                                                   https://www.pennovation.upenn.edu/
# 417                                         https://pci.upenn.edu/entrepreneurs/i-corps/
# 418                                                    https://injury.research.chop.edu/
# ...

# %%
from requests_html import HTMLSession
embedded_links = []
for i in df_links.url:
    embedded_link = []
    self_domain = i.split('/')[2].replace('www.','')
    session = HTMLSession()
    try: 
        r = session.get(i)
        links = pd.Series(list(r.html.absolute_links))
        links = links.loc[links.str.startswith('http')]
        # print(links)
        for i in links:
        #     domain = i.split('/')[2].replace('www,', '')
        #     # print(domain)
        #     if domain != self_domain and domain in domain_set:
            # embedded_link.append(i)
            embedded_links.append(i)
    except:
        embedded_links.append('na')
        continue
# Out:
# /var/folders/m5/tw1ymsrj4jjg5vcyxyqy8r280000gn/T/ipykernel_2866/783650818.py:9: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   links = pd.Series(list(r.html.absolute_links))

# %%
len(embedded_links)
# Out:
# 31468

# %%
len(list(set(embedded_links)))
# Out:
# 8464

# %%
emb = list(set(embedded_links))
emb
# Out:
# ['https://www.aacsb.edu/insights/articles/2021/06/priming-the-academic-pipeline',
#  'https://www.dental.upenn.edu/research/research-overview/research-day-2022/research-day-poster-awards/',
#  'https://penntoday.upenn.edu/schools/nursing',
#  'https://upenn.technologypublisher.com/?Test_Inteum_Tech_Publisher_PCI%5BrefinementList%5D%5Bkeywords%5D%5B0%5D=Nanotechnology',
#  'https://www.sp2.upenn.edu/sp2-event/financial-wellness-peer-counseling/2022-11-24/',
#  'https://jacobslevycenter.wharton.upenn.edu/',
#  'https://belabs.seas.upenn.edu/media/student-projects',
#  'https://mgmt.wharton.upenn.edu/department-info/directions-office-map/',
#  'https://wistar.org/featured-news/expanding-learning-opportunities-diverse-scientists',
#  'https://www.dental.upenn.edu/patient-care-facilities/',
#  'https://catalog.upenn.edu/search/?P=HCIN%206180',
#  'https://cemb.upenn.edu/about-cemb/staff/',
#  'https://injury.research.chop.edu/traumatic-stress/completed-and-foundational-projects',
# ...

# %%
innovat_in_link = [i for i in emb if i.contain("innovat")]
innovat_in_link
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [45], line 1
# ----> 1 innovat_in_link = [i for i in emb if i.contain("innovat")]
#       2 innovat_in_link
#
# Cell In [45], line 1, in <listcomp>(.0)
# ----> 1 innovat_in_link = [i for i in emb if i.contain("innovat")]
#       2 innovat_in_link
#
# AttributeError: 'str' object has no attribute 'contain'

# %%
emb
# Out:
# [0     https://www.nursing.upenn.edu/admissions/phd-a...
#  1     https://penno365.sharepoint.com/teams/Schoolof...
#  2               https://www.nursing.upenn.edu/research/
#  3     https://www.nursing.upenn.edu/innovation/innov...
#  4                        http://twitter.com/PennNursing
#  5     https://www.nursing.upenn.edu/innovation/innov...
#  6         https://www.nursing.upenn.edu/about/contacts/
#  7     https://www.nursing.upenn.edu/about/visitor-in...
#  8                               https://www.penn4c.org/
#  9                     http://instagram.com/pennnursing/
#  10    https://www.nursing.upenn.edu/innovation/front...
#  11    https://www.nursing.upenn.edu/live/events/4060...
#  12    https://www.nursing.upenn.edu/live/files/842-p...
#  13            https://www.nursing.upenn.edu/admissions/
#  14                  http://www.facebook.com/PennNursing
#  15         https://www.nursing.upenn.edu/global-health/
# ...

# %%
with pd.ExcelWriter('branch.xlsx') as writer:  
    df_branch.to_excel(writer, sheet_name='branch', index=False)
    df_branch_innovat.to_excel(writer, sheet_name="innovat_in_branch")

# %%
domains_clickable = []
domains_clean = []
for link in df_links.url:
    link_element = link.split('/')
    domains_clickable.append("https://" + link_element[2])
    domains_clean.append(link_element[2].replace('www.',''))

# %%
df_links['domains_clickable'] = domains_clickable
df_links['domains_clean'] = domains_clean
df_links = df_links[~df_links.domains_clickable.isin(EXCLUDE_DOMAIN)]
len(list(set(df_links.domains_clickable)))
# Out:
# 68

# %%
df_links
# Out:
#                                                    url  \
# 0            https://www.nursing.upenn.edu/innovation/
# 1    https://www.nursing.upenn.edu/innovation/innov...
# 2    https://knowledge.wharton.upenn.edu/article/bu...
# 3    https://knowledge.wharton.upenn.edu/category/i...
# 4    https://www.med.upenn.edu/evpdean/innovation.html
# ..                                                 ...
# 417       https://pci.upenn.edu/entrepreneurs/i-corps/
# 418                  https://injury.research.chop.edu/
# 419                       https://www.itmat.upenn.edu/
# 420             https://bakerretail.wharton.upenn.edu/
# 421  https://www.impact.upenn.edu/franklin-sp2-soci...
#
#                          domains_clickable                  domains_clean
# 0            https://www.nursing.upenn.edu              nursing.upenn.edu
# 1            https://www.nursing.upenn.edu              nursing.upenn.edu
# 2      https://knowledge.wharton.upenn.edu    knowledge.wharton.upenn.edu
# ...

# %%
import requests

innovate_count = []
for i in df_links.url:
    session = HTMLSession()
    # page = requests.get(i, verify=False)
    # count = page.text.lower().count('innovat')
    print(i)
    try: 
        r = session.get(i)
        count = r.html.full_text.lower().count('innovat')
        innovate_count.append(count)
    except: 
        continue
innovate_count
# Out:
# https://www.nursing.upenn.edu/innovation/
# https://www.nursing.upenn.edu/innovation/innovation-accelerator/
# https://knowledge.wharton.upenn.edu/article/business-model-innovation-matters-ever/
# https://knowledge.wharton.upenn.edu/category/innovation/
# https://www.med.upenn.edu/evpdean/innovation.html
# https://executiveeducation.wharton.upenn.edu/for-individuals/all-programs/mastering-innovation-strategy-process-and-tools/
# https://healthcareinnovation.upenn.edu/
# https://globalyouth.wharton.upenn.edu/programs-courses/essentials-of-innovation/
# https://www.law.upenn.edu/institutes/ctic/
# https://pc3i.upenn.edu/
# https://www.hr.upenn.edu/PennHR/penn-community/inclusion-innovation-impact
# https://knowledge.wharton.upenn.edu/article/innovation-networks-looking-for-ideas-outside-the-company/
# https://pci.upenn.edu/
# https://mackinstitute.wharton.upenn.edu/2020/innovation-metrics-for-success-digital-era/
# https://knowledge.wharton.upenn.edu/article/data-analytics-innovation/
# ...

# %%
df_links['innovate_count'] = innovate_count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [222], line 1
# ----> 1 df_links['innovate_count'] = innovate_count
#
# NameError: name 'innovate_count' is not defined

# %%
df_links[df_links['innovate_count']==0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'innovate_count'
#
# ...

# %% [markdown]
# Collapsed spreadsheet: domains, Col: how many pages are there, and how many times innovation is mentioned

# %%
df_links.groupby('domains_clean')['url'].count()
# Out:
# domains_clean
# accelerationlab.upenn.edu        1
# aisp.upenn.edu                   1
# almanac.upenn.edu                3
# asc.upenn.edu                    1
# bakerretail.wharton.upenn.edu    1
#                                 ..
# wistar.org                       1
# wrds-wharton.upenn.edu           1
# wsp.wharton.upenn.edu            2
# yourimpact.upenn.edu             1
# yprize.upenn.edu                 1
# Name: url, Length: 67, dtype: int64

# %%
groupby_domain = pd.DataFrame(df_links.groupby('domains_clean')['url'].count())

# %%
groupby_domain['innovate_count'] = df_links.groupby('domains_clean')['innovate_count'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [34], line 1
# ----> 1 groupby_domain['innovate_count'] = df_links.groupby('domains_clean')['innovate_count'].sum()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/groupby/generic.py:1538, in DataFrameGroupBy.__getitem__(self, key)
#    1529 if isinstance(key, tuple) and len(key) > 1:
#    1530     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1531     # valid syntax, so don't raise warning
#    1532     warnings.warn(
#    1533         "Indexing with multiple keys (implicitly converted to a tuple "
#    1534         "of keys) will be deprecated, use a list instead.",
#    1535         FutureWarning,
#    1536         stacklevel=2,
#    1537     )
# -> 1538 return super().__getitem__(key)
#
# ...

# %%
groupby_domain.rename(columns={'url':'page_count'}, inplace=True)

# %%
groupby_domain[groupby_domain['innovate_count']==0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'innovate_count'
#
# ...

# %% [markdown]
# ### site-site matrix

# %%
with pd.ExcelWriter('site_domainV2.xlsx') as writer:  
    df_links.to_excel(writer, sheet_name='site', index=False)
    groupby_domain.to_excel(writer, sheet_name='domain')

# %%
df_domain = pd.read_excel('site_domainV2.xlsx')

# %%
df_domain.domain
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 df_domain.domain
#
# NameError: name 'df_domain' is not defined

# %%
domain_set = [i.split('/')[2].replace('www.','') if len(i.split('/'))>= 2 else 'None' for i in df_domain.domain]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [106], line 1
# ----> 1 domain_set = [i.split('/')[2].replace('www.','') if len(i.split('/'))>= 2 else 'None' for i in df_domain.domain]
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:5487, in NDFrame.__getattr__(self, name)
#    5480 if (
#    5481     name not in self._internal_names_set
#    5482     and name not in self._metadata
#    5483     and name not in self._accessors
#    5484     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5485 ):
#    5486     return self[name]
# -> 5487 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'domain'

# %%
df_links
# Out:
#                                                    url  \
# 0            https://www.nursing.upenn.edu/innovation/
# 1    https://www.nursing.upenn.edu/innovation/innov...
# 2    https://knowledge.wharton.upenn.edu/article/bu...
# 3    https://knowledge.wharton.upenn.edu/category/i...
# 4    https://www.med.upenn.edu/evpdean/innovation.html
# ..                                                 ...
# 417       https://pci.upenn.edu/entrepreneurs/i-corps/
# 418                  https://injury.research.chop.edu/
# 419                       https://www.itmat.upenn.edu/
# 420             https://bakerretail.wharton.upenn.edu/
# 421  https://www.impact.upenn.edu/franklin-sp2-soci...
#
#                          domains_clickable                  domains_clean
# 0            https://www.nursing.upenn.edu              nursing.upenn.edu
# 1            https://www.nursing.upenn.edu              nursing.upenn.edu
# 2      https://knowledge.wharton.upenn.edu    knowledge.wharton.upenn.edu
# ...

# %%
len(set(domain_set)), len(set(df_links.domains_clean))
# Out:
# (67, 67)

# %%
domain_set = set(df_links.domains_clean)
domain_set
# Out:
# {'accelerationlab.upenn.edu',
#  'aisp.upenn.edu',
#  'almanac.upenn.edu',
#  'asc.upenn.edu',
#  'bakerretail.wharton.upenn.edu',
#  'belabs.seas.upenn.edu',
#  'cemb.upenn.edu',
#  'chop.edu',
#  'dental.upenn.edu',
#  'design.upenn.edu',
#  'eent.seas.upenn.edu',
#  'executiveeducation.wharton.upenn.edu',
#  'executivemba.wharton.upenn.edu',
#  'globalyouth.wharton.upenn.edu',
#  'grasp.upenn.edu',
#  'gse.upenn.edu',
#  'gutmann-archived.president.upenn.edu',
#  'healthcareinnovation.upenn.edu',
#  'healthtech.upenn.edu',
#  'impact.upenn.edu',
#  'improvinghealthcare.mehp.upenn.edu',
#  'injury.research.chop.edu',
#  'itmat.upenn.edu',
#  'knowledge.wharton.upenn.edu',
#  'law.upenn.edu',
#  'ldi.upenn.edu',
#  'library.upenn.edu',
#  'mackinstitute.wharton.upenn.edu',
#  'magazine.wharton.upenn.edu',
#  'mba.wharton.upenn.edu',
#  'med.upenn.edu',
#  'medicalethicshealthpolicy.med.upenn.edu',
#  'mgmt.wharton.upenn.edu',
#  'nano.upenn.edu',
#  'nursing.upenn.edu',
# ...

# %%
from requests_html import HTMLSession
embedded_links = []
for i in ['https://yprize.upenn.edu/']:
    embedded_link = []
    self_domain = i.split('/')[2].replace('www.','')
    session = HTMLSession()
    try: 
        r = session.get(i)
        links = pd.Series(list(r.html.absolute_links))
        links_filter = links.loc[links.str.startswith('http')]
        print(links_filter)
        for j in links:
            domain = j.split('/')[2].replace('www.', '')
            print(domain)
            if domain != self_domain and domain in domain_set:
                embedded_link.append(j)
        embedded_links.append(embedded_link)
    except:
        embedded_links.append('na')
        continue
embedded_links
# Out:
# 0            https://yprize.upenn.edu/2022-finalists-2/
# 1     https://yprize.upenn.edu/about-the-competition...
# 2     https://yprize.upenn.edu/submit-your-y-prize-p...
# 3          https://yprize.upenn.edu/steering-committee/
# 4      https://yprize.upenn.edu/2022-finalists-2/#ossum
# 5                      https://yprize.upenn.edu/videos/
# 6     https://www.linkedin.com/company/mack-institut...
# 7       https://yprize.upenn.edu/submission-guidelines/
# 8        https://yprize.upenn.edu/past-y-prize-winners/
# 9     https://yprize.upenn.edu/about-the-competition-2/
# 10       https://yprize.upenn.edu/about-the-technology/
# 11             https://mackinstitute.wharton.upenn.edu/
# 12    https://yprize.upenn.edu/the-history-of-the-y-...
# 13             https://form.jotform.com/223027686553965
# 14                   https://yprize.upenn.edu/sponsors/
# 15      https://yprize.upenn.edu/recommended-resources/
# 16                            https://yprize.upenn.edu/
# ...

# %%
from requests_html import HTMLSession
embedded_links = []
for i in df_links.url:
    embedded_link = []
    self_domain = i.split('/')[2].replace('www.','')
    session = HTMLSession()
    try: 
        r = session.get(i)
        links = pd.Series(list(r.html.absolute_links))
        links_filter = links.loc[links.str.startswith('http')]
        # print(links_filter)
        for j in links_filter:
            domain = j.split('/')[2].replace('www.', '')
            # print(domain)
            if domain != self_domain and domain in domain_set:
                embedded_link.append(j)
        embedded_links.append(embedded_link)
    except:
        embedded_links.append('na')
        continue
# Out:
# /var/folders/m5/tw1ymsrj4jjg5vcyxyqy8r280000gn/T/ipykernel_47168/1107696442.py:9: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   links = pd.Series(list(r.html.absolute_links))

# %%
df_links['embedded_links'] = embedded_links

# %%
df_links
# Out:
#                                                    url  \
# 0            https://www.nursing.upenn.edu/innovation/
# 1    https://www.nursing.upenn.edu/innovation/innov...
# 2    https://knowledge.wharton.upenn.edu/article/bu...
# 3    https://knowledge.wharton.upenn.edu/category/i...
# 4    https://www.med.upenn.edu/evpdean/innovation.html
# ..                                                 ...
# 417       https://pci.upenn.edu/entrepreneurs/i-corps/
# 418                  https://injury.research.chop.edu/
# 419                       https://www.itmat.upenn.edu/
# 420             https://bakerretail.wharton.upenn.edu/
# 421  https://www.impact.upenn.edu/franklin-sp2-soci...
#
#                          domains_clickable                  domains_clean  \
# 0            https://www.nursing.upenn.edu              nursing.upenn.edu
# 1            https://www.nursing.upenn.edu              nursing.upenn.edu
# 2      https://knowledge.wharton.upenn.edu    knowledge.wharton.upenn.edu
# ...

# %%
embedded_links_count = [len(x) for x in embedded_links]
df_links['embedded_links_count'] = embedded_links_count

# %%
new_df = df_links.explode('embedded_links')

# %%
new_df
# Out:
#                                                    url  \
# 0            https://www.nursing.upenn.edu/innovation/
# 1    https://www.nursing.upenn.edu/innovation/innov...
# 2    https://knowledge.wharton.upenn.edu/article/bu...
# 2    https://knowledge.wharton.upenn.edu/article/bu...
# 2    https://knowledge.wharton.upenn.edu/article/bu...
# ..                                                 ...
# 420             https://bakerretail.wharton.upenn.edu/
# 420             https://bakerretail.wharton.upenn.edu/
# 420             https://bakerretail.wharton.upenn.edu/
# 421  https://www.impact.upenn.edu/franklin-sp2-soci...
# 421  https://www.impact.upenn.edu/franklin-sp2-soci...
#
#                          domains_clickable                  domains_clean  \
# 0            https://www.nursing.upenn.edu              nursing.upenn.edu
# 1            https://www.nursing.upenn.edu              nursing.upenn.edu
# 2      https://knowledge.wharton.upenn.edu    knowledge.wharton.upenn.edu
# ...

# %%
new_df[new_df['url']=='https://yprize.upenn.edu/']
# Out:
#                            url         domains_clickable     domains_clean  \
# 410  https://yprize.upenn.edu/  https://yprize.upenn.edu  yprize.upenn.edu
# 410  https://yprize.upenn.edu/  https://yprize.upenn.edu  yprize.upenn.edu
# 410  https://yprize.upenn.edu/  https://yprize.upenn.edu  yprize.upenn.edu
# 410  https://yprize.upenn.edu/  https://yprize.upenn.edu  yprize.upenn.edu
#
#                                embedded_links  embedded_links_count
# 410  https://mackinstitute.wharton.upenn.edu/                     4
# 410             https://venturelab.upenn.edu/                     4
# 410                    https://pci.upenn.edu/                     4
# 410               https://www.seas.upenn.edu/                     4

# %%
new_df.isnull().sum()
# Out:
# url                      0
# domains_clickable        0
# domains_clean            0
# embedded_links          64
# embedded_links_count     0
# dtype: int64

# %%
new_df.dropna(inplace=True)

# %%
new_df['embedded_domains'] = [i.split('/')[2].replace('www.','') if len(i.split('/'))>= 2 else 'None' for i in new_df.embedded_links]

# %%
new_df = new_df[new_df.domains_clean.isin(domain_set)]

# %%
new_df
# Out:
#                                                    url  \
# 2    https://knowledge.wharton.upenn.edu/article/bu...
# 2    https://knowledge.wharton.upenn.edu/article/bu...
# 2    https://knowledge.wharton.upenn.edu/article/bu...
# 2    https://knowledge.wharton.upenn.edu/article/bu...
# 2    https://knowledge.wharton.upenn.edu/article/bu...
# ..                                                 ...
# 420             https://bakerretail.wharton.upenn.edu/
# 420             https://bakerretail.wharton.upenn.edu/
# 420             https://bakerretail.wharton.upenn.edu/
# 421  https://www.impact.upenn.edu/franklin-sp2-soci...
# 421  https://www.impact.upenn.edu/franklin-sp2-soci...
#
#                          domains_clickable                  domains_clean  \
# 2      https://knowledge.wharton.upenn.edu    knowledge.wharton.upenn.edu
# 2      https://knowledge.wharton.upenn.edu    knowledge.wharton.upenn.edu
# 2      https://knowledge.wharton.upenn.edu    knowledge.wharton.upenn.edu
# ...

# %%
domain_domain = pd.DataFrame(new_df.groupby(['domains_clean', 'embedded_domains'])['embedded_domains'].count())

# %%
domain_domain
# Out:
#                                                                     embedded_domains
# domains_clean                 embedded_domains
# accelerationlab.upenn.edu     healthcareinnovation.upenn.edu                       3
# almanac.upenn.edu             gse.upenn.edu                                        3
#                               nursing.upenn.edu                                    3
# bakerretail.wharton.upenn.edu executiveeducation.wharton.upenn.edu                 2
#                               executivemba.wharton.upenn.edu                       1
# ...                                                                              ...
# yourimpact.upenn.edu          penntoday.upenn.edu                                  1
# yprize.upenn.edu              mackinstitute.wharton.upenn.edu                      1
#                               pci.upenn.edu                                        1
# ...

# %%
with pd.ExcelWriter('domain_domain.xlsx') as writer:
    domain_domain.to_excel(writer, sheet_name='domain_domain')

# %%
domain_domain.to_csv('domain_domain.csv')

# %% [markdown]
# ## Network Analysis

# %%
import networkx as nx

# %%
G = nx.Graph()
G.add_nodes_from([1, 2, 3])
G.nodes()

G.add_edge(1, 2)
G.edges()

# %%
destination_dir = 'home/mgmt/wanxing/html_data/'

# %%
from requests_html import HTMLSession
session = HTMLSession()
r = session.get('https://venturelab.upenn.edu')
link_list = r.html.links

# %%
for i in link_list:
    print(i)
# Out:
# https://canvas.upenn.edu/courses/1572944
# https://venturelab.upenn.edu/Tangen/social-entrepreneurship-speaker-series-miranda-wang-of-novoloop
# https://venturelab.upenn.edu/our-team
# https://venturelab.upenn.edu/digital-design-studio
# https://www.instagram.com/weareventurelab/
# https://venturelab.upenn.edu/venture-lab-events
# https://venturelab.upenn.edu/investor-pathway
# https://venturelab.upenn.edu/navigator-pathway
# https://venturelab.upenn.edu/directions-hours-parking
# https://venturelab.upenn.edu/founder-profile-series-jacob-donnini
# ...

# %%
link_list
# Out:
# {'/',
#  'http://hellowaffa.org',
#  'http://seas.upenn.edu',
#  'http://upenn.edu',
#  'http://wharton.upenn.edu',
#  'http://www.whartonangelnetwork.co/',
#  'https://accessibility.web-resources.upenn.edu/get-help',
#  'https://alumni.mbacareers.wharton.upenn.edu/',
#  'https://apps.wharton.upenn.edu/spaces/create',
#  'https://canvas.upenn.edu/courses/1572944',
#  'https://careerservices.upenn.edu/',
#  'https://entrepreneurship.wharton.upenn.edu/startup-challenge/',
#  'https://giving.apps.upenn.edu/fund?program=WHA&fund=600271&_ga=2.157341178.135507603.1642008743-1807704723.1642008743',
#  'https://goo.gl/maps/zzEjXHCwNFKbCPoP9',
#  'https://mgmt.wharton.upenn.edu/profile/rosenkol/',
#  'https://mgmt.wharton.upenn.edu/programs/mba/entrepreneurship-innovation/',
#  'https://mgmt.wharton.upenn.edu/programs/undergraduate/entrepreneurship-innovation-concentration/',
#  'https://operations.wharton.upenn.edu/security/',
# ...

# %%
import urllib.request
import os
link = links.url[2]
domain_name=[]
print(link)
link_element = link.split('/')
link_element[2] = link_element[2].replace("www.","")
reversed_element  = link_element[2].split('.')[::-1]
print(reversed_element)
reversed_element = ['.'.join(reversed_element[:i][::-1]) for i in range(1,len(reversed_element)+1)]
print(reversed_element)
link_element[2] = '/'.join(reversed_element)
print(len(link_element))
if len(link_element) <= 4:
    domain_name.append(link_element[2])
else:
    for i in range(2, len(link_element)-2):
        if len(link_element[i]) != 0:
            domain_name.append(link_element[i])
html_name = link_element[-2]
# print(link_element)
domain_name = '/'.join(domain_name)
print(domain_name)
print(link)
filepath = '/Users/wanxing/PycharmProjects/PennEcosystem/html_data/c3i'
filepath = os.path.join(destination_dir, domain_name)
print(filepath)
if not os.path.exists(filepath):
    if not os.path.exists(destination_dir):
        os.makedirs(destination_dir)
    os.makedirs(filepath)
filename = os.path.join(filepath, html_name+".html")
urllib.request.urlretrieve(link, filename)

# %%
lst= requests.get(url[0], verify=False)
lst= sum(lst.text.count(x) for x in ('innovation', 'innovations', 'innovate'))

# %%
import urllib.request
import os

destination_dir = 'home/mgmt/wanxing/html_data/'
# print(link)
for link in links:
    domain_name=[]
    link_element = link.split('/')
    link_element[2] = link_element[2].replace("www.","").replace(".edu","")
    reversed_element  = link_element[2].split('.')[::-1]
    link_element[2] = '/'.join(reversed_element)
    for i in range(2, len(link_element)-2):
        if len(link_element[i]) != 0:
            domain_name.append(link_element[i])
    name = link_element[-2]
    # print(link_element)
    domain_name = '/'.join(domain_name)
    # print(domain)
    # print(link)
    # filepath = '/Users/wanxing/PycharmProjects/PennEcosystem/html_data/c3i'
    filepath = os.path.join(destination_dir, domain_name)
    # print(filepath)
    if not os.path.exists(filepath):
        if not os.path.exists(destination_dir):
            os.makedirs(destination_dir)
        os.makedirs(filepath)
    filename = os.path.join(filepath, name+".html")
    try:
        urllib.request.urlretrieve(link, filename)
    except:
        continue
    # print(filename)
    print("Downloading "+name)
    time.sleep(5)

# %%
## Google search
import time
import urllib.request
import os

text= "innovation"
domain = "q=site%3Aupenn.edu+"
links = [] # Initiate empty list to capture final results
destination_dir = 'smb://hpcc.wharton.upenn.edu/wanxing/html_data/'
# Specify number of pages on google search, each page contains 10 #links

n_pages = 14200
for page in range(1, n_pages):
    # print(page)
    url = "https://www.google.com/search?" + domain + text + "&start=" + str((page - 1) * 10)
    # print(url)
    driver.get(url)
    soup = bs4.BeautifulSoup(driver.page_source, 'html.parser')
    # print(soup)
    search = soup.find_all('div', class_="yuRUbf")
    # print(search)
    for h in search:
        links.append(h.a.get('href'))
    for h in search:
        domain=[]
        link = h.a.get('href')
        # print(link)
        if link is not None:
            link_element = link.split('/')
            link_element[2] = link_element[2].replace("www.","").replace(".upenn.edu","")
            for i in range(2, len(link_element)-2):
                if len(link_element[i]) != 0:
                    domain.append(link_element[i])
            name = link_element[-2]
            # print(link_element)
            domain = '/'.join(domain)
            title = h.a.text
            links.append(link)
            # print(domain)
            # print(link)
            # filepath = '/Users/wanxing/PycharmProjects/PennEcosystem/html_data/c3i'
            filepath = os.path.join(destination_dir, domain)
            # print(filepath)
            if not os.path.exists(filepath):
                if not os.path.exists(destination_dir):
                    os.makedirs(destination_dir)
                os.makedirs(filepath)
            filename = os.path.join(filepath, name+".html")
            try:
                urllib.request.urlretrieve(link, filename)
            except:
                continue
            # print(filename)
            print("Downloading "+title)
            time.sleep(10)

# %%
links

# %%
import pandas as pd
links = pd.DataFrame(links, columns=['link'])
links.to_csv('links.csv')

# %%
# import urllib.request
# import os
# # Penn Website search https://www.upenn.edu/search
# text= "innovation"
# links = [] # Initiate empty list to capture final results
# destination_dir = '/Users/wanxing/PycharmProjects/PennEcosystem/html_data/'
# # Specify number of pages on google search, each page contains 10 #links

# n_pages = 20
# for page in range(1, n_pages):
#    #https://www.upenn.edu/search?as_q=innovation#gsc.tab=0&gsc.q=innovation&gsc.page=1 
#     url = "https://www.upenn.edu/search?as_q=" + text + "#gsc.tab=0&gsc.q=innovation&gsc.page=" + str((page))
#     driver.get(url)
#     soup = bs4.BeautifulSoup(driver.page_source, 'html.parser')
#     search = soup.find_all('div', class_="gsc-thumbnail-inside")
#     for h in search:
#         domain=[]
#         link = h.a.get('href')
#         # print(link)
#         if link is not None:
#             link_element = link.split('/')
#             for i in range(2, len(link_element)):
#                 if len(link_element[i]) != 0:
#                     domain.append(link_element[i])
#             domain = '/'.join(domain)
#             title = h.a.text
#             links.append(link)
#             print(page)
#             print(domain)
#             print(link)

#             filepath = os.path.join(destination_dir, domain)
#             print(filepath)
#             if not os.path.exists(filepath):
#                 if not os.path.exists(destination_dir):
#                     os.makedirs(destination_dir)
#                 os.makedirs(filepath)
#             try:
#                 urllib.request.urlretrieve(link, filepath+'.html')
#             except:
#                 continue
#             print("Downloading "+title)

# %%
#   # Make two strings with default google search URL
# # 'https://google.com/search?q=' and
# # our customized search keyword.
# # Concatenate them
# text= "innovation"
# domain = "site%3Aupenn.edu+"
# url = 'https://google.com/search?q=' + domain + text
  
# # Fetch the URL data using requests.get(url),
# # store it in a variable, request_result.
# request_result=requests.get( url )
  
# # Creating soup from the fetched request
# soup = bs4.BeautifulSoup(request_result.text,
#                          "html.parser")
# print(soup)

# %%
# # soup.find.all( h3 ) to grab 
# # all major headings of our search result,
# heading_object=soup.find_all( 'h3' )
  
# # Iterate through the object 
# # and print it as a string.
# for info in heading_object:
#     print(info.getText())
#     print("------")
